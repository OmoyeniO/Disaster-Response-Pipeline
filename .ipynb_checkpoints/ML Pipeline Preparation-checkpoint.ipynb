# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import sys
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.base import BaseEstimator, TransformerMixin
import joblib
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/omoyeniogundipe/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/omoyeniogundipe/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/omoyeniogundipe/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/omoyeniogundipe/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages (3.3.2)
# Requirement already satisfied: numpy in /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scipy in /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages (from lightgbm) (1.6.2)
# Requirement already satisfied: wheel in /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages (from lightgbm) (0.36.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages (from lightgbm) (1.1.1)
# Requirement already satisfied: joblib>=1.0.0 in /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)

# %%
import lightgbm as lgb

# %%
from sklearn.decomposition import TruncatedSVD
import pickle

# %%
# load data from database
engine = create_engine('sqlite:///Disaster_response.db')
df = pd.read_sql_table('Messages', engine)
X = df['message']
Y = df.drop(columns=['id','message','original','genre'])

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    '''
    Tokenize, lemmatize, normalize, strip, remove stop words from the text
    
    :param text: input text
    '''
    # Initialization
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    stopWords = set(stopwords.words('english'))
    
    # Get clean tokens after lemmatization, normalization, stripping and stop words removal
    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        if tok not in stopWords:
            clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])

# %%
#pipeline.get_params()

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size= 0.2, random_state = 50)

# %%
# train classifier
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x7fef1ec80af0>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
def test_model(model, X_test, y_test):
    '''Function to test the model, report the F1 score, precision and recall for each output category (classification report).
    Input: Model, test set for X and y
    Output: Prints classification report
    '''
    y_pred = model.predict(X_test)
    
    for i, col in enumerate (y_test):
        print (col)
        print (classification_report (y_test[col], y_pred[:, i]))
        
test_model(pipeline, X_test, y_test)
# Out:
# related
#               precision    recall  f1-score   support
#
#            0       0.75      0.34      0.47      1183
#            1       0.83      0.97      0.89      4025
#            2       0.71      0.14      0.23        36
#
#     accuracy                           0.82      5244
#    macro avg       0.76      0.48      0.53      5244
# weighted avg       0.81      0.82      0.79      5244
#
# request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      4322
#            1       0.86      0.50      0.63       922
#
#     accuracy                           0.90      5244
#    macro avg       0.88      0.74      0.79      5244
# weighted avg       0.89      0.90      0.89      5244
#
# offer
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5210
#            1       0.00      0.00      0.00        34
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81      2991
#            1       0.77      0.68      0.72      2253
#
#     accuracy                           0.77      5244
#    macro avg       0.77      0.76      0.77      5244
# weighted avg       0.77      0.77      0.77      5244
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4810
#            1       0.65      0.05      0.09       434
#
#     accuracy                           0.92      5244
#    macro avg       0.78      0.52      0.53      5244
# weighted avg       0.90      0.92      0.89      5244
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4987
#            1       0.81      0.09      0.15       257
#
#     accuracy                           0.95      5244
#    macro avg       0.88      0.54      0.57      5244
# weighted avg       0.95      0.95      0.94      5244
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5094
#            1       0.86      0.04      0.08       150
#
#     accuracy                           0.97      5244
#    macro avg       0.91      0.52      0.53      5244
# weighted avg       0.97      0.97      0.96      5244
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5155
#            1       0.00      0.00      0.00        89
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.97      0.98      0.97      5244
#
# military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5080
#            1       0.79      0.09      0.16       164
#
#     accuracy                           0.97      5244
#    macro avg       0.88      0.55      0.57      5244
# weighted avg       0.97      0.97      0.96      5244
#
# child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5244
#
#     accuracy                           1.00      5244
#    macro avg       1.00      1.00      1.00      5244
# weighted avg       1.00      1.00      1.00      5244
#
# water
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4890
#            1       0.89      0.33      0.48       354
#
#     accuracy                           0.95      5244
#    macro avg       0.92      0.66      0.73      5244
# weighted avg       0.95      0.95      0.94      5244
#
# food
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4628
#            1       0.86      0.57      0.69       616
#
#     accuracy                           0.94      5244
#    macro avg       0.91      0.78      0.83      5244
# weighted avg       0.94      0.94      0.93      5244
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4771
#            1       0.87      0.33      0.47       473
#
#     accuracy                           0.93      5244
#    macro avg       0.90      0.66      0.72      5244
# weighted avg       0.93      0.93      0.92      5244
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5159
#            1       0.60      0.07      0.13        85
#
#     accuracy                           0.98      5244
#    macro avg       0.79      0.53      0.56      5244
# weighted avg       0.98      0.98      0.98      5244
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5114
#            1       1.00      0.03      0.06       130
#
#     accuracy                           0.98      5244
#    macro avg       0.99      0.52      0.52      5244
# weighted avg       0.98      0.98      0.96      5244
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5186
#            1       0.00      0.00      0.00        58
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# refugees
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5064
#            1       0.57      0.02      0.04       180
#
#     accuracy                           0.97      5244
#    macro avg       0.77      0.51      0.51      5244
# weighted avg       0.95      0.97      0.95      5244
#
# death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4993
#            1       0.89      0.19      0.31       251
#
#     accuracy                           0.96      5244
#    macro avg       0.92      0.59      0.64      5244
# weighted avg       0.96      0.96      0.95      5244
#
# other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      4529
#            1       0.59      0.02      0.05       715
#
#     accuracy                           0.86      5244
#    macro avg       0.73      0.51      0.49      5244
# weighted avg       0.83      0.86      0.81      5244
#
# infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4905
#            1       0.00      0.00      0.00       339
#
#     accuracy                           0.94      5244
#    macro avg       0.47      0.50      0.48      5244
# weighted avg       0.87      0.94      0.90      5244
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4997
#            1       0.70      0.08      0.14       247
#
#     accuracy                           0.95      5244
#    macro avg       0.83      0.54      0.56      5244
# weighted avg       0.94      0.95      0.94      5244
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4965
#            1       0.81      0.12      0.21       279
#
#     accuracy                           0.95      5244
#    macro avg       0.88      0.56      0.59      5244
# weighted avg       0.95      0.95      0.93      5244
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5137
#            1       1.00      0.05      0.09       107
#
#     accuracy                           0.98      5244
#    macro avg       0.99      0.52      0.54      5244
# weighted avg       0.98      0.98      0.97      5244
#
# tools
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5219
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      1.00      0.99      5244
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5185
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5222
#            1       0.00      0.00      0.00        22
#
#     accuracy                           1.00      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      1.00      0.99      5244
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5187
#            1       0.00      0.00      0.00        57
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5009
#            1       0.00      0.00      0.00       235
#
#     accuracy                           0.95      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.91      0.95      0.93      5244
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      3766
#            1       0.87      0.67      0.76      1478
#
#     accuracy                           0.88      5244
#    macro avg       0.87      0.81      0.84      5244
# weighted avg       0.88      0.88      0.87      5244
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4800
#            1       0.92      0.44      0.60       444
#
#     accuracy                           0.95      5244
#    macro avg       0.94      0.72      0.79      5244
# weighted avg       0.95      0.95      0.94      5244
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      4728
#            1       0.76      0.46      0.58       516
#
#     accuracy                           0.93      5244
#    macro avg       0.85      0.72      0.77      5244
# weighted avg       0.93      0.93      0.93      5244
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5184
#            1       1.00      0.02      0.03        60
#
#     accuracy                           0.99      5244
#    macro avg       0.99      0.51      0.51      5244
# weighted avg       0.99      0.99      0.98      5244
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4742
#            1       0.90      0.73      0.81       502
#
#     accuracy                           0.97      5244
#    macro avg       0.94      0.86      0.89      5244
# weighted avg       0.96      0.97      0.96      5244
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5137
#            1       0.88      0.07      0.12       107
#
#     accuracy                           0.98      5244
#    macro avg       0.93      0.53      0.56      5244
# weighted avg       0.98      0.98      0.97      5244
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4979
#            1       0.53      0.03      0.06       265
#
#     accuracy                           0.95      5244
#    macro avg       0.74      0.51      0.52      5244
# weighted avg       0.93      0.95      0.93      5244
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      4203
#            1       0.83      0.37      0.51      1041
#
#     accuracy                           0.86      5244
#    macro avg       0.85      0.68      0.71      5244
# weighted avg       0.86      0.86      0.84      5244
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = {'tfidf__use_idf': (True, False), 
              'clf__estimator__n_estimators': [50, 100], 
              'clf__estimator__min_samples_split': [2, 4]} 

cv = GridSearchCV(pipeline, param_grid= parameters, n_jobs =1)

# %%
cv
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x7fef1ec80af0>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              n_jobs=1,
#              param_grid={'clf__estimator__min_samples_split': [2, 4],
#                          'clf__estimator__n_estimators': [50, 100],
#                          'tfidf__use_idf': (True, False)})

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x7fef1ec80af0>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              n_jobs=1,
#              param_grid={'clf__estimator__min_samples_split': [2, 4],
#                          'clf__estimator__n_estimators': [50, 100],
#                          'tfidf__use_idf': (True, False)})

# %%
test_model(cv, X_test, y_test)
# Out:
# related
#               precision    recall  f1-score   support
#
#            0       0.75      0.35      0.47      1183
#            1       0.83      0.97      0.89      4025
#            2       0.80      0.11      0.20        36
#
#     accuracy                           0.82      5244
#    macro avg       0.79      0.47      0.52      5244
# weighted avg       0.81      0.82      0.79      5244
#
# request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      4322
#            1       0.86      0.50      0.63       922
#
#     accuracy                           0.90      5244
#    macro avg       0.88      0.74      0.79      5244
# weighted avg       0.89      0.90      0.89      5244
#
# offer
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5210
#            1       0.00      0.00      0.00        34
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81      2991
#            1       0.76      0.69      0.73      2253
#
#     accuracy                           0.78      5244
#    macro avg       0.77      0.77      0.77      5244
# weighted avg       0.78      0.78      0.77      5244
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4810
#            1       0.75      0.06      0.10       434
#
#     accuracy                           0.92      5244
#    macro avg       0.84      0.53      0.53      5244
# weighted avg       0.91      0.92      0.89      5244
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4987
#            1       0.80      0.06      0.12       257
#
#     accuracy                           0.95      5244
#    macro avg       0.88      0.53      0.55      5244
# weighted avg       0.95      0.95      0.93      5244
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5094
#            1       0.91      0.07      0.12       150
#
#     accuracy                           0.97      5244
#    macro avg       0.94      0.53      0.56      5244
# weighted avg       0.97      0.97      0.96      5244
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5155
#            1       0.00      0.00      0.00        89
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.97      0.98      0.97      5244
#
# military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5080
#            1       0.67      0.07      0.13       164
#
#     accuracy                           0.97      5244
#    macro avg       0.82      0.54      0.56      5244
# weighted avg       0.96      0.97      0.96      5244
#
# child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5244
#
#     accuracy                           1.00      5244
#    macro avg       1.00      1.00      1.00      5244
# weighted avg       1.00      1.00      1.00      5244
#
# water
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4890
#            1       0.87      0.31      0.45       354
#
#     accuracy                           0.95      5244
#    macro avg       0.91      0.65      0.71      5244
# weighted avg       0.95      0.95      0.94      5244
#
# food
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4628
#            1       0.86      0.60      0.70       616
#
#     accuracy                           0.94      5244
#    macro avg       0.90      0.79      0.84      5244
# weighted avg       0.94      0.94      0.94      5244
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      4771
#            1       0.85      0.35      0.49       473
#
#     accuracy                           0.94      5244
#    macro avg       0.89      0.67      0.73      5244
# weighted avg       0.93      0.94      0.92      5244
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5159
#            1       0.58      0.08      0.14        85
#
#     accuracy                           0.98      5244
#    macro avg       0.78      0.54      0.57      5244
# weighted avg       0.98      0.98      0.98      5244
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5114
#            1       1.00      0.04      0.07       130
#
#     accuracy                           0.98      5244
#    macro avg       0.99      0.52      0.53      5244
# weighted avg       0.98      0.98      0.97      5244
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5186
#            1       0.00      0.00      0.00        58
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# refugees
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5064
#            1       0.67      0.07      0.12       180
#
#     accuracy                           0.97      5244
#    macro avg       0.82      0.53      0.55      5244
# weighted avg       0.96      0.97      0.95      5244
#
# death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4993
#            1       0.86      0.14      0.25       251
#
#     accuracy                           0.96      5244
#    macro avg       0.91      0.57      0.61      5244
# weighted avg       0.95      0.96      0.94      5244
#
# other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      4529
#            1       0.62      0.03      0.05       715
#
#     accuracy                           0.86      5244
#    macro avg       0.74      0.51      0.49      5244
# weighted avg       0.83      0.86      0.81      5244
#
# infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4905
#            1       0.00      0.00      0.00       339
#
#     accuracy                           0.94      5244
#    macro avg       0.47      0.50      0.48      5244
# weighted avg       0.87      0.94      0.90      5244
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4997
#            1       0.71      0.08      0.15       247
#
#     accuracy                           0.96      5244
#    macro avg       0.84      0.54      0.56      5244
# weighted avg       0.95      0.96      0.94      5244
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4965
#            1       0.81      0.13      0.22       279
#
#     accuracy                           0.95      5244
#    macro avg       0.88      0.56      0.60      5244
# weighted avg       0.95      0.95      0.93      5244
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5137
#            1       1.00      0.06      0.11       107
#
#     accuracy                           0.98      5244
#    macro avg       0.99      0.53      0.55      5244
# weighted avg       0.98      0.98      0.97      5244
#
# tools
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5219
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      1.00      0.99      5244
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5185
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5222
#            1       0.00      0.00      0.00        22
#
#     accuracy                           1.00      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      1.00      0.99      5244
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5187
#            1       0.00      0.00      0.00        57
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5009
#            1       0.00      0.00      0.00       235
#
#     accuracy                           0.95      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.91      0.95      0.93      5244
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      3766
#            1       0.87      0.69      0.77      1478
#
#     accuracy                           0.88      5244
#    macro avg       0.88      0.82      0.85      5244
# weighted avg       0.88      0.88      0.88      5244
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4800
#            1       0.95      0.42      0.58       444
#
#     accuracy                           0.95      5244
#    macro avg       0.95      0.71      0.78      5244
# weighted avg       0.95      0.95      0.94      5244
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      4728
#            1       0.75      0.49      0.59       516
#
#     accuracy                           0.93      5244
#    macro avg       0.85      0.73      0.78      5244
# weighted avg       0.93      0.93      0.93      5244
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5184
#            1       0.00      0.00      0.00        60
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4742
#            1       0.90      0.74      0.81       502
#
#     accuracy                           0.97      5244
#    macro avg       0.94      0.87      0.90      5244
# weighted avg       0.97      0.97      0.97      5244
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5137
#            1       0.91      0.09      0.17       107
#
#     accuracy                           0.98      5244
#    macro avg       0.95      0.55      0.58      5244
# weighted avg       0.98      0.98      0.97      5244
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4979
#            1       0.50      0.02      0.04       265
#
#     accuracy                           0.95      5244
#    macro avg       0.73      0.51      0.51      5244
# weighted avg       0.93      0.95      0.93      5244
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      4203
#            1       0.82      0.37      0.51      1041
#
#     accuracy                           0.86      5244
#    macro avg       0.84      0.68      0.72      5244
# weighted avg       0.86      0.86      0.84      5244
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
pipeline2 = Pipeline([
    ('vect', CountVectorizer()),
    ('best', TruncatedSVD()),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(lgb.LGBMClassifier()))
])

# %%
pipeline2.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect', CountVectorizer()),
#   ('best', TruncatedSVD()),
#   ('tfidf', TfidfTransformer()),
#   ('clf', MultiOutputClassifier(estimator=LGBMClassifier()))],
#  'verbose': False,
#  'vect': CountVectorizer(),
#  'best': TruncatedSVD(),
#  'tfidf': TfidfTransformer(),
#  'clf': MultiOutputClassifier(estimator=LGBMClassifier()),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': None,
#  'vect__vocabulary': None,
#  'best__algorithm': 'randomized',
#  'best__n_components': 2,
#  'best__n_iter': 5,
#  'best__random_state': None,
#  'best__tol': 0.0,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__boosting_type': 'gbdt',
#  'clf__estimator__class_weight': None,
#  'clf__estimator__colsample_bytree': 1.0,
#  'clf__estimator__importance_type': 'split',
#  'clf__estimator__learning_rate': 0.1,
#  'clf__estimator__max_depth': -1,
#  'clf__estimator__min_child_samples': 20,
#  'clf__estimator__min_child_weight': 0.001,
#  'clf__estimator__min_split_gain': 0.0,
#  'clf__estimator__n_estimators': 100,
#  'clf__estimator__n_jobs': -1,
#  'clf__estimator__num_leaves': 31,
#  'clf__estimator__objective': None,
#  'clf__estimator__random_state': None,
#  'clf__estimator__reg_alpha': 0.0,
#  'clf__estimator__reg_lambda': 0.0,
#  'clf__estimator__silent': True,
#  'clf__estimator__subsample': 1.0,
#  'clf__estimator__subsample_for_bin': 200000,
#  'clf__estimator__subsample_freq': 0,
#  'clf__estimator': LGBMClassifier(),
#  'clf__n_jobs': None}

# %%
#Train & predict
pipeline2.fit(X_train, y_train)
test_model(pipeline2, X_test, y_test)
# Out:
# related
#               precision    recall  f1-score   support
#
#            0       0.36      0.01      0.01      1183
#            1       0.77      1.00      0.87      4025
#            2       1.00      0.03      0.05        36
#
#     accuracy                           0.77      5244
#    macro avg       0.71      0.34      0.31      5244
# weighted avg       0.68      0.77      0.67      5244
#
# request
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      4322
#            1       0.00      0.00      0.00       922
#
#     accuracy                           0.82      5244
#    macro avg       0.41      0.50      0.45      5244
# weighted avg       0.68      0.82      0.74      5244
#
# offer
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5210
#            1       0.00      0.00      0.00        34
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.58      0.90      0.70      2991
#            1       0.49      0.12      0.20      2253
#
#     accuracy                           0.57      5244
#    macro avg       0.53      0.51      0.45      5244
# weighted avg       0.54      0.57      0.49      5244
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4810
#            1       0.00      0.00      0.00       434
#
#     accuracy                           0.92      5244
#    macro avg       0.46      0.50      0.48      5244
# weighted avg       0.84      0.92      0.88      5244
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4987
#            1       0.00      0.00      0.00       257
#
#     accuracy                           0.95      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.90      0.95      0.93      5244
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5094
#            1       0.00      0.00      0.00       150
#
#     accuracy                           0.97      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.94      0.97      0.96      5244
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5155
#            1       0.00      0.00      0.00        89
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.97      0.98      0.97      5244
#
# military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5080
#            1       0.00      0.00      0.00       164
#
#     accuracy                           0.97      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.94      0.97      0.95      5244
#
# child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5244
#
#     accuracy                           1.00      5244
#    macro avg       1.00      1.00      1.00      5244
# weighted avg       1.00      1.00      1.00      5244
#
# water
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97      4890
#            1       0.00      0.00      0.00       354
#
#     accuracy                           0.93      5244
#    macro avg       0.47      0.50      0.48      5244
# weighted avg       0.87      0.93      0.90      5244
#
# food
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4628
#            1       0.00      0.00      0.00       616
#
#     accuracy                           0.88      5244
#    macro avg       0.44      0.50      0.47      5244
# weighted avg       0.78      0.88      0.83      5244
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      4771
#            1       0.00      0.00      0.00       473
#
#     accuracy                           0.91      5244
#    macro avg       0.45      0.50      0.48      5244
# weighted avg       0.83      0.91      0.87      5244
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5159
#            1       0.00      0.00      0.00        85
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.97      0.98      0.98      5244
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5114
#            1       0.00      0.00      0.00       130
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.95      0.98      0.96      5244
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5186
#            1       0.00      0.00      0.00        58
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5064
#            1       0.00      0.00      0.00       180
#
#     accuracy                           0.97      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.93      0.97      0.95      5244
#
# death
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4993
#            1       0.00      0.00      0.00       251
#
#     accuracy                           0.95      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.91      0.95      0.93      5244
#
# other_aid
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4529
#            1       0.00      0.00      0.00       715
#
#     accuracy                           0.86      5244
#    macro avg       0.43      0.50      0.46      5244
# weighted avg       0.75      0.86      0.80      5244
#
# infrastructure_related
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4905
#            1       0.00      0.00      0.00       339
#
#     accuracy                           0.94      5244
#    macro avg       0.47      0.50      0.48      5244
# weighted avg       0.87      0.94      0.90      5244
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4997
#            1       0.00      0.00      0.00       247
#
#     accuracy                           0.95      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.91      0.95      0.93      5244
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4965
#            1       0.00      0.00      0.00       279
#
#     accuracy                           0.95      5244
#    macro avg       0.47      0.50      0.49      5244
# weighted avg       0.90      0.95      0.92      5244
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5137
#            1       0.00      0.00      0.00       107
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.96      0.98      0.97      5244
#
# tools
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5219
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      1.00      0.99      5244
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5185
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5222
#            1       0.00      0.00      0.00        22
#
#     accuracy                           1.00      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      1.00      0.99      5244
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5187
#            1       0.00      0.00      0.00        57
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5009
#            1       0.00      0.00      0.00       235
#
#     accuracy                           0.96      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.91      0.96      0.93      5244
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.72      0.99      0.84      3766
#            1       0.51      0.02      0.03      1478
#
#     accuracy                           0.72      5244
#    macro avg       0.62      0.50      0.43      5244
# weighted avg       0.66      0.72      0.61      5244
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4800
#            1       0.00      0.00      0.00       444
#
#     accuracy                           0.92      5244
#    macro avg       0.46      0.50      0.48      5244
# weighted avg       0.84      0.92      0.87      5244
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4728
#            1       0.00      0.00      0.00       516
#
#     accuracy                           0.90      5244
#    macro avg       0.45      0.50      0.47      5244
# weighted avg       0.81      0.90      0.85      5244
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5184
#            1       0.00      0.00      0.00        60
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      4742
#            1       0.56      0.02      0.04       502
#
#     accuracy                           0.90      5244
#    macro avg       0.73      0.51      0.49      5244
# weighted avg       0.87      0.90      0.86      5244
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5137
#            1       0.00      0.00      0.00       107
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.96      0.98      0.97      5244
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4979
#            1       0.00      0.00      0.00       265
#
#     accuracy                           0.95      5244
#    macro avg       0.47      0.50      0.49      5244
# weighted avg       0.90      0.95      0.92      5244
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      4203
#            1       0.00      0.00      0.00      1041
#
#     accuracy                           0.80      5244
#    macro avg       0.40      0.50      0.44      5244
# weighted avg       0.64      0.80      0.71      5244
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Param tunning 
parameters2 = { #'vect__ngram_range': ((1, 1), (1, 2)), 
              #'vect__max_df': (0.5, 1.0), 
              #'vect__max_features': (None, 5000), 
              'tfidf__use_idf': (True, False), 
              'clf__estimator__n_estimators': [50, 100],
              'clf__estimator__learning_rate': [1,2] }

# %%
cv2 = GridSearchCV(pipeline2, param_grid=parameters2)
cv2
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect', CountVectorizer()),
#                                        ('best', TruncatedSVD()),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=LGBMClassifier()))]),
#              param_grid={'clf__estimator__learning_rate': [1, 2],
#                          'clf__estimator__n_estimators': [50, 100],
#                          'tfidf__use_idf': (True, False)})

# %%
cv2.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect', CountVectorizer()),
#                                        ('best', TruncatedSVD()),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=LGBMClassifier()))]),
#              param_grid={'clf__estimator__learning_rate': [1, 2],
#                          'clf__estimator__n_estimators': [50, 100],
#                          'tfidf__use_idf': (True, False)})

# %%
test_model(cv2, X_test, y_test)
# Out:
# related
#               precision    recall  f1-score   support
#
#            0       0.24      0.19      0.21      1183
#            1       0.77      0.82      0.79      4025
#            2       0.00      0.00      0.00        36
#
#     accuracy                           0.67      5244
#    macro avg       0.34      0.33      0.33      5244
# weighted avg       0.64      0.67      0.66      5244
#
# request
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      4322
#            1       0.00      0.00      0.00       922
#
#     accuracy                           0.82      5244
#    macro avg       0.41      0.50      0.45      5244
# weighted avg       0.68      0.82      0.74      5244
#
# offer
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5210
#            1       0.00      0.00      0.00        34
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.58      0.84      0.69      2991
#            1       0.47      0.19      0.27      2253
#
#     accuracy                           0.56      5244
#    macro avg       0.53      0.51      0.48      5244
# weighted avg       0.53      0.56      0.51      5244
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4810
#            1       0.00      0.00      0.00       434
#
#     accuracy                           0.92      5244
#    macro avg       0.46      0.50      0.48      5244
# weighted avg       0.84      0.92      0.88      5244
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4987
#            1       0.00      0.00      0.00       257
#
#     accuracy                           0.95      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.90      0.95      0.93      5244
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5094
#            1       0.00      0.00      0.00       150
#
#     accuracy                           0.97      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.94      0.97      0.96      5244
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      5155
#            1       0.01      0.01      0.01        89
#
#     accuracy                           0.96      5244
#    macro avg       0.50      0.49      0.49      5244
# weighted avg       0.97      0.96      0.96      5244
#
# military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5080
#            1       0.00      0.00      0.00       164
#
#     accuracy                           0.97      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.94      0.97      0.95      5244
#
# child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5244
#
#     accuracy                           1.00      5244
#    macro avg       1.00      1.00      1.00      5244
# weighted avg       1.00      1.00      1.00      5244
#
# water
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      4890
#            1       0.00      0.00      0.00       354
#
#     accuracy                           0.93      5244
#    macro avg       0.47      0.50      0.48      5244
# weighted avg       0.87      0.93      0.90      5244
#
# food
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4628
#            1       0.00      0.00      0.00       616
#
#     accuracy                           0.88      5244
#    macro avg       0.44      0.50      0.47      5244
# weighted avg       0.78      0.88      0.83      5244
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      4771
#            1       0.00      0.00      0.00       473
#
#     accuracy                           0.91      5244
#    macro avg       0.45      0.50      0.48      5244
# weighted avg       0.83      0.91      0.87      5244
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5159
#            1       0.00      0.00      0.00        85
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.97      0.98      0.98      5244
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5114
#            1       0.00      0.00      0.00       130
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.95      0.98      0.96      5244
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5186
#            1       0.02      0.02      0.02        58
#
#     accuracy                           0.98      5244
#    macro avg       0.51      0.50      0.51      5244
# weighted avg       0.98      0.98      0.98      5244
#
# refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5064
#            1       0.00      0.00      0.00       180
#
#     accuracy                           0.97      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.93      0.97      0.95      5244
#
# death
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4993
#            1       0.00      0.00      0.00       251
#
#     accuracy                           0.95      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.91      0.95      0.93      5244
#
# other_aid
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4529
#            1       0.00      0.00      0.00       715
#
#     accuracy                           0.86      5244
#    macro avg       0.43      0.50      0.46      5244
# weighted avg       0.75      0.86      0.80      5244
#
# infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4905
#            1       0.00      0.00      0.00       339
#
#     accuracy                           0.94      5244
#    macro avg       0.47      0.50      0.48      5244
# weighted avg       0.87      0.94      0.90      5244
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      4997
#            1       0.00      0.00      0.00       247
#
#     accuracy                           0.95      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.91      0.95      0.93      5244
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4965
#            1       0.00      0.00      0.00       279
#
#     accuracy                           0.95      5244
#    macro avg       0.47      0.50      0.49      5244
# weighted avg       0.90      0.95      0.92      5244
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5137
#            1       0.00      0.00      0.00       107
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.96      0.98      0.97      5244
#
# tools
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      5219
#            1       0.01      0.08      0.02        25
#
#     accuracy                           0.95      5244
#    macro avg       0.50      0.52      0.50      5244
# weighted avg       0.99      0.95      0.97      5244
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5185
#            1       0.03      0.03      0.03        59
#
#     accuracy                           0.98      5244
#    macro avg       0.51      0.51      0.51      5244
# weighted avg       0.98      0.98      0.98      5244
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5222
#            1       0.00      0.00      0.00        22
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5187
#            1       0.03      0.02      0.02        57
#
#     accuracy                           0.98      5244
#    macro avg       0.51      0.51      0.51      5244
# weighted avg       0.98      0.98      0.98      5244
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5009
#            1       0.00      0.00      0.00       235
#
#     accuracy                           0.96      5244
#    macro avg       0.48      0.50      0.49      5244
# weighted avg       0.91      0.96      0.93      5244
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83      3766
#            1       0.43      0.04      0.08      1478
#
#     accuracy                           0.71      5244
#    macro avg       0.57      0.51      0.45      5244
# weighted avg       0.64      0.71      0.62      5244
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4800
#            1       0.00      0.00      0.00       444
#
#     accuracy                           0.92      5244
#    macro avg       0.46      0.50      0.48      5244
# weighted avg       0.84      0.92      0.87      5244
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      4728
#            1       0.00      0.00      0.00       516
#
#     accuracy                           0.90      5244
#    macro avg       0.45      0.50      0.47      5244
# weighted avg       0.81      0.90      0.85      5244
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5184
#            1       0.02      0.02      0.02        60
#
#     accuracy                           0.98      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.98      0.98      0.98      5244
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      4742
#            1       0.46      0.02      0.05       502
#
#     accuracy                           0.90      5244
#    macro avg       0.68      0.51      0.50      5244
# weighted avg       0.86      0.90      0.86      5244
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5137
#            1       0.00      0.00      0.00       107
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.96      0.98      0.97      5244
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4979
#            1       0.00      0.00      0.00       265
#
#     accuracy                           0.95      5244
#    macro avg       0.47      0.50      0.49      5244
# weighted avg       0.90      0.95      0.92      5244
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      4203
#            1       0.00      0.00      0.00      1041
#
#     accuracy                           0.80      5244
#    macro avg       0.40      0.50      0.44      5244
# weighted avg       0.64      0.80      0.71      5244
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/omoyeniogundipe/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
with open('disaster_model.pkl', 'wb') as f:
    pickle.dump(cv2, f)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.

# %%
engine = create_engine('sqlite:///Disaster_response.db')
df = pd.read_sql_table("Messages",engine)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize)
#     279     try:
# --> 280         meta.reflect(only=[table_name], views=True)
#     281     except sqlalchemy.exc.InvalidRequestError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4702                     s = schema and (" schema '%s'" % schema) or ""
# -> 4703                     raise exc.InvalidRequestError(
#    4704                         "Could not reflect: requested table(s) not available "
#
# InvalidRequestError: Could not reflect: requested table(s) not available in Engine(sqlite:///Disaster_response.db): (Messages)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-741454d3d914> in <module>
#       1 engine = create_engine('sqlite:///Disaster_response.db')
# ----> 2 df = pd.read_sql_table("Messages",engine)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize)
#     280         meta.reflect(only=[table_name], views=True)
#     281     except sqlalchemy.exc.InvalidRequestError as err:
# --> 282         raise ValueError(f"Table {table_name} not found") from err
#     283
#     284     pandas_sql = SQLDatabase(con, meta=meta)
#
# ValueError: Table Messages not found

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine.has_table('Messages')
# Out:
# <ipython-input-9-db68077e7491>:1: SADeprecationWarning: The Engine.has_table() method is deprecated and will be removed in a future release.  Please refer to Inspector.has_table(). (deprecated since: 1.4)
#   engine.has_table('Messages')
# False
